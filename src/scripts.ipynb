# %% [markdown]
# # Jupyter Notebook
# ## Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from core import core_funcs as cf

# %matplotlib widget

# %% [markdown]
# ## Computation

# %%
x = np.linspace(-2, 2, 100)
y = x**2

# %% [markdown]
# ## Visualization

# %%
plt.figure()
plt.plot(x, y)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## pd.DataFrame

# %%
df = pd.DataFrame(data=[x, y], index=["x", "y"]).T
df
# Out:
#            x         y
# 0  -2.000000  4.000000
# 1  -1.959596  3.840016
# 2  -1.919192  3.683298
# 3  -1.878788  3.529844
# 4  -1.838384  3.379655
# ..       ...       ...
# 95  1.838384  3.379655
# 96  1.878788  3.529844
# 97  1.919192  3.683298
# 98  1.959596  3.840016
# 99  2.000000  4.000000
#
# [100 rows x 2 columns]

# %%
inp_l = [1, 2, 3]
cf.ext_list(inp_l, 10, 20)
# Out:
# 30
